# %%
import requests

url = 'https://www.koreaexim.go.kr/site/program/financial/exchangeJSON'

params = {
    'authkey':'2YejuR3NOAbLGLn7SvH1ncMJuEQYwSY9',
    'data':'AP01'
}

response = requests.get(url,params)
data = response.json()

def currency_info():
    for item in data:
        country_name = item['cur_nm']
        country_sym = item['cur_unit']
        exchange_rate = item['deal_bas_r']
        print(f"{country_name}, 1{country_sym} = {exchange_rate}원")

currency_info()
# Out:
# 아랍에미리트 디르함, 1AED = 351.63원
# 호주 달러, 1AUD = 878.35원
# 바레인 디나르, 1BHD = 3,425.82원
# 브루나이 달러, 1BND = 963.84원
# 캐나다 달러, 1CAD = 981.46원
# 스위스 프랑, 1CHF = 1,447.38원
# 위안화, 1CNH = 179.54원
# 덴마아크 크로네, 1DKK = 190.59원
# 유로, 1EUR = 1,419.68원
# 영국 파운드, 1GBP = 1,649.5원
# 홍콩 달러, 1HKD = 164.98원
# 인도네시아 루피아, 1IDR(100) = 8.64원
# 일본 옌, 1JPY(100) = 911.5원
# 한국 원, 1KRW = 1원
# 쿠웨이트 디나르, 1KWD = 4,203.96원
# 말레이지아 링기트, 1MYR = 278.04원
# 노르웨이 크로네, 1NOK = 121.36원
# 뉴질랜드 달러, 1NZD = 801.89원
# 사우디 리얄, 1SAR = 344.26원
# 스웨덴 크로나, 1SEK = 121.22원
# 싱가포르 달러, 1SGD = 963.84원
# 태국 바트, 1THB = 37.14원
# 미국 달러, 1USD = 1,291.5원

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

# Chrome 웹 드라이버 옵션 설정
options = Options()

options.headless = True

driver = webdriver.Chrome(options=options) 

driver.get('http://www.smbs.biz/ExRate/TodayExRate.jsp')

nation_elements = driver.find_elements(By.CSS_SELECTOR, 'p[class^="nation"]')
rate_elements = driver.find_elements(By.CSS_SELECTOR, 'strong[class^="txt_point"]')

# 국가명과 환율 정보 출력
for nation_element, rate_element in zip(nation_elements, rate_elements):
    country = nation_element.get_attribute('innerText').strip()
    rate = rate_element.get_attribute('innerText').strip().replace(',', '')
    print(f"{country} 원")

driver.quit()
# Out:
# C:\Users\oem\AppData\Local\Temp\ipykernel_14588\1691659689.py:9: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True
# 스웨덴 SEK  121.22 원
# 영국 GBP (US$)  1,649.50 원
# 노르웨이 NOK  121.36 원
# 덴마크 DKK  190.59 원
# 유로 EUR (US$)  1,419.68 원
# 스위스 CHF  1,447.38 원
#  원
# 쿠웨이트 KWD  4,203.96 원
# 일본 JPY (100)  911.50 원
# 바레인 BHD  3,425.82 원
# 홍콩 HKD  164.98 원
# 사우디아라비아 SAR 344.26 원
# 아랍에미리트 AED  351.63 원
# 태국 THB  37.14 원
# 말레이시아 MYR  278.04 원
# 싱가포르 SGD  963.84 원
# 인도네시아 IDR (100)  8.64 원
# 호주 AUD (US$)  878.35 원
# 뉴질랜드 NZD (US$)  801.89 원
# 캐나다 CAD  981.46 원
# 미국 USD  1,291.50 원
# 위안 CNH  179.54 원
# 대만 TWD  41.75 원
# 몽골 MNT  0.37 원
# 카자흐스탄 KZT  2.88 원
# 필리핀 PHP  23.23 원
# 베트남 VND (100)  5.49 원
# 브루나이 BND  963.84 원
# 인도 INR  15.76 원
# 파키스탄 PKR  4.50 원
# 방글라데시 BDT  11.94 원
# 멕시코 MXN  75.38 원
# 브라질 BRL  271.11 원
# 아르헨티나 ARS  5.13 원
# 러시아 RUB  15.44 원
# 헝가리 HUF  3.84 원
# 폴란드 PLN  320.13 원
# 체코 CZK  59.81 원
# 카타르 QAR  354.47 원
# 이스라엘 ILS  356.52 원
# 요르단 JOD  1,820.55 원
# 튀르키예 TRY  54.82 원
# 남아프리카공화국 ZAR  70.49 원
# 이집트 EGP  41.80 원
# 캄보디아 KHR  0.31 원
# 마카오 MOP  160.10 원
# 네팔 NPR  9.84 원
# 스리랑카 LKR  4.21 원
# 우즈베키스탄 UZS  0.11 원
# 미얀마 MMK  0.62 원
# 칠레 CLP  1.61 원
# 콜롬비아 COP  0.31 원
# 루마니아 RON  286.04 원

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

options = Options()

options.headless = True

driver = webdriver.Chrome(options=options) 

driver.get('http://www.smbs.biz/ExRate/TodayExRate.jsp')


nation_elements = driver.find_elements(By.CSS_SELECTOR, 'p[class^="nation"]:not(.nation7)')
rate_elements = driver.find_elements(By.CSS_SELECTOR, 'strong[class^="txt_point"]')

exchange_rates = {}
for nation_element, rate_element in zip(nation_elements, rate_elements):
    country = nation_element.get_attribute('innerText').strip()
    rate = rate_element.get_attribute('innerText').strip().replace(',', '')
    exchange_rates[country] = rate

print(exchange_rates)
a = exchange_rates.get('스웨덴 SEK\xa0 121.22')
print(a)

country_name = input('국가 이름: ')

if country_name in exchange_rates:
    rate = exchange_rates[country_name]
    print(f"{country_name}: {rate} 원")
else:
    print(f"{country_name}환율 정보 없음")


driver.quit()
# Out:
# C:\Users\oem\AppData\Local\Temp\ipykernel_14588\2972550939.py:8: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True
# {'스웨덴 SEK\xa0 121.22': '121.22', '영국 GBP (US$)\xa0 1,649.50': '1649.50', '노르웨이 NOK\xa0 121.36': '121.36', '덴마크 DKK\xa0 190.59': '190.59', '유로 EUR (US$)\xa0 1,419.68': '1419.68', '스위스 CHF\xa0 1,447.38': '1447.38', '쿠웨이트 KWD\xa0 4,203.96': '4203.96', '일본 JPY (100)\xa0 911.50': '911.50', '바레인 BHD\xa0 3,425.82': '3425.82', '홍콩 HKD\xa0 164.98': '164.98', '사우디아라비아 SAR 344.26': '344.26', '아랍에미리트 AED\xa0 351.63': '351.63', '태국 THB\xa0 37.14': '37.14', '말레이시아 MYR\xa0 278.04': '278.04', '싱가포르 SGD\xa0 963.84': '963.84', '인도네시아 IDR (100)\xa0 8.64': '8.64', '호주 AUD (US$)\xa0 878.35': '878.35', '뉴질랜드 NZD (US$)\xa0 801.89': '801.89', '캐나다 CAD\xa0 981.46': '981.46', '미국 USD\xa0 1,291.50': '1291.50', '위안 CNH\xa0 179.54': '179.54', '대만 TWD\xa0 41.75': '41.75', '몽골 MNT\xa0 0.37': '2.88', '카자흐스탄 KZT\xa0 2.88': '23.23', '필리핀 PHP\xa0 23.23': '5.49', '베트남 VND (100)\xa0 5.49': '963.84', '브루나이 BND\xa0 963.84': '15.76', '인도 INR\xa0 15.76': '4.50', '파키스탄 PKR\xa0 4.50': '11.94', '방글라데시 BDT\xa0 11.94': '75.38', '멕시코 MXN\xa0 75.38': '271.11', '브라질 BRL\xa0 271.11': '5.13', '아르헨티나 ARS\xa0 5.13': '15.44', '러시아 RUB\xa0 15.44': '3.84', '헝가리 HUF\xa0 3.84': '320.13', '폴란드 PLN\xa0 320.13': '59.81', '체코 CZK\xa0 59.81': '354.47', '카타르 QAR\xa0 354.47': '356.52', '이스라엘 ILS\xa0 356.52': '1820.55', '요르단 JOD\xa0 1,820.55': '54.82', '튀르키예 TRY\xa0 54.82': '70.49', '남아프리카공화국 ZAR\xa0 70.49': '41.80', '이집트 EGP\xa0 41.80': '160.10', '캄보디아 KHR\xa0 0.31': '9.84', '마카오 MOP\xa0 160.10': '4.21', '네팔 NPR\xa0 9.84': '0.62', '스리랑카 LKR\xa0 4.21': '1.61', '우즈베키스탄 UZS\xa0 0.11': '286.04', '미얀마 MMK\xa0 0.62': '3354.63', '칠레 CLP\xa0 1.61': '9.21', '콜롬비아 COP\xa0 0.31': '269.07', '루마니아 RON\xa0 286.04': '23.50', '오만 OMR\xa0 3,354.63': '579.50'}
# 121.22
# 미국환율 정보 없음

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

options = Options()
options.headless = True

driver = webdriver.Chrome(options=options) 
driver.get('http://www.smbs.biz/ExRate/TodayExRate.jsp')

nation_elements = driver.find_elements(By.CSS_SELECTOR, 'p[class^="nation"]:not(.nation7)')
rate_elements = driver.find_elements(By.CSS_SELECTOR, 'strong[class^="txt_point"]')
exchange_rates = {}
# units = []
for nation_element, rate_element in zip(nation_elements, rate_elements):
    # print(rate_element)
    country = nation_element.get_attribute('innerText').strip()
    rate = rate_element.get_attribute('innerText').strip()
    unit = rate_element.get_attribute('id').strip()
    # units.append(unit)
    # 국가 이름만 추출
    country_name = country.split(' ')[0]

    exchange_rates[country_name] = rate
    print(rate)
    print(unit)

print(exchange_rates)
country_name = input('국가 이름: ')

if country_name in exchange_rates:
    rate = exchange_rates[country_name]
    
    print(f"{country_name}, 1{unit.upper()}: {rate} 원")
else:
    print(f"{country_name}의 환율 정보가 없습니다.")

driver.quit()
# Out:
# C:\Users\oem\AppData\Local\Temp\ipykernel_14588\456016528.py:6: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True
# 121.22
# sek
# 1,649.50
# gbp
# 121.36
# nok
# 190.59
# dkk
# 1,419.68
# eur
# 1,447.38
# chf
# 4,203.96
# kwd
# 911.50
# jpy
# 3,425.82
# bhd
# 164.98
# hkd
# 344.26
# sar
# 351.63
# aed
# 37.14
# thb
# 278.04
# myr
# 963.84
# sgd
# 8.64
# idr
# 878.35
# aud
# 801.89
# nzd
# 981.46
# cad
# 1,291.50
# usd
# 179.54
# cnh
# 41.75
# twd
# 2.88
# kzt
# 23.23
# php
# 5.49
# vnd
# 963.84
# bnd
# 15.76
# inr
# 4.50
# pkr
# 11.94
# bdt
# 75.38
# mxn
# 271.11
# brl
# 5.13
# ars
# 15.44
# rub
# 3.84
# huf
# 320.13
# pln
# 59.81
# czk
# 354.47
# qar
# 356.52
# ils
# 1,820.55
# jod
# 54.82
# try
# 70.49
# zar
# 41.80
# egp
# 160.10
# mop
# 9.84
# npr
# 4.21
# lkr
# 0.62
# mmk
# 1.61
# clp
# 286.04
# ron
# 3,354.63
# omr
# 9.21
# kes
# 269.07
# lyd
# 23.50
# etb
# 579.50
# fjd
# {'스웨덴': '121.22', '영국': '1,649.50', '노르웨이': '121.36', '덴마크': '190.59', '유로': '1,419.68', '스위스': '1,447.38', '쿠웨이트': '4,203.96', '일본': '911.50', '바레인': '3,425.82', '홍콩': '164.98', '사우디아라비아': '344.26', '아랍에미리트': '351.63', '태국': '37.14', '말레이시아': '278.04', '싱가포르': '963.84', '인도네시아': '8.64', '호주': '878.35', '뉴질랜드': '801.89', '캐나다': '981.46', '미국': '1,291.50', '위안': '179.54', '대만': '41.75', '몽골': '2.88', '카자흐스탄': '23.23', '필리핀': '5.49', '베트남': '963.84', '브루나이': '15.76', '인도': '4.50', '파키스탄': '11.94', '방글라데시': '75.38', '멕시코': '271.11', '브라질': '5.13', '아르헨티나': '15.44', '러시아': '3.84', '헝가리': '320.13', '폴란드': '59.81', '체코': '354.47', '카타르': '356.52', '이스라엘': '1,820.55', '요르단': '54.82', '튀르키예': '70.49', '남아프리카공화국': '41.80', '이집트': '160.10', '캄보디아': '9.84', '마카오': '4.21', '네팔': '0.62', '스리랑카': '1.61', '우즈베키스탄': '286.04', '미얀마': '3,354.63', '칠레': '9.21', '콜롬비아': '269.07', '루마니아': '23.50', '오만': '579.50'}
# 스웨덴, 1FJD: 121.22 원
